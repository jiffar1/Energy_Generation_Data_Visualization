# %% [markdown]
# #                    Energy Generation Exploratory Data Analysis

# %% [markdown]
# #For this Visualization I selected a data set from the World Resources Institute which contains electricity generation from over 28000 power plants across the world.
# #The DATA is titled "Global Power Plant Database".
# #It contains 22 COLUMNS and 28664 ROWS

# %% [markdown]
# Visit the following link for source of the data:
#
# http://datasets.wri.org/dataset/globalpowerplantdatabase

# %% [markdown]
# # Data Analysis and Visualization:

# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/jja/Downloads'

# %%
power_data = pd.read_csv('/Users/jja/Downloads/globalpowerplantdatabasev110/global_power_plant_database.csv')

# %%
#The data contains a mixture of numerical and catagorical values
power_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28664 entries, 0 to 28663
# Data columns (total 22 columns):
# country                     28664 non-null object
# country_long                28664 non-null object
# name                        28644 non-null object
# gppd_idnr                   28664 non-null object
# capacity_mw                 28664 non-null float64
# latitude                    28664 non-null float64
# longitude                   28664 non-null float64
# fuel1                       28661 non-null object
# fuel2                       1705 non-null object
# fuel3                       296 non-null object
# fuel4                       108 non-null object
# commissioning_year          14952 non-null float64
# owner                       18093 non-null object
# source                      28664 non-null object
# url                         28664 non-null object
# geolocation_source          28243 non-null object
# year_of_capacity_data       16145 non-null float64
# ...

# %%
#There are 22 columns and 28664 rows.
power_data.shape
# Out:
# (28664, 22)

# %%
power_data.head()
# Out:
#   country country_long                                               name  \
# 0     AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1     AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 2     AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 3     AFG  Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 4     AFG  Afghanistan            Northwest Kabul Power Plant Afghanistan
#
#       gppd_idnr  capacity_mw  latitude  longitude  fuel1 fuel2 fuel3  \
# 0  GEODB0040538        33.00   32.3220    65.1190  Hydro   NaN   NaN
# 1  GEODB0040541        66.00   34.5560    69.4787  Hydro   NaN   NaN
# 2  GEODB0040534       100.00   34.6410    69.7170  Hydro   NaN   NaN
# 3  GEODB0040536        11.55   34.4847    70.3633  Hydro   NaN   NaN
# 4  GEODB0040540        42.00   34.5638    69.1134    Gas   NaN   NaN
#
#              ...            owner  source                                 url  \
# ...

# %%
power_data.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'fuel1', 'fuel2', 'fuel3', 'fuel4',
#        'commissioning_year', 'owner', 'source', 'url', 'geolocation_source',
#        'year_of_capacity_data', 'generation_gwh_2013', 'generation_gwh_2014',
#        'generation_gwh_2015', 'generation_gwh_2016',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
power_data['country_long'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Antarctica',
#        'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahrain', 'Bangladesh', 'Belarus', 'Belgium', 'Benin', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Central African Republic', 'Chile', 'China', 'Colombia', 'Congo',
#        'Costa Rica', 'Cote DIvoire', 'Croatia', 'Cuba', 'Cyprus',
#        'Czech Republic', 'Democratic Republic of the Congo', 'Denmark',
#        'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Ethiopia', 'Fiji', 'Finland', 'France', 'French Guiana', 'Gabon',
#        'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Guatemala',
#        'Guinea', 'Guinea-Bissau', 'Guyana', 'Honduras', 'Hungary',
# ...

# %%
power_data['country'].unique()
# Out:
# array(['AFG', 'ALB', 'DZA', 'AGO', 'ATA', 'ARG', 'ARM', 'AUS', 'AUT',
#        'AZE', 'BHR', 'BGD', 'BLR', 'BEL', 'BEN', 'BTN', 'BOL', 'BIH',
#        'BWA', 'BRA', 'BRN', 'BGR', 'BFA', 'BDI', 'KHM', 'CMR', 'CAN',
#        'CPV', 'CAF', 'CHL', 'CHN', 'COL', 'COG', 'CRI', 'CIV', 'HRV',
#        'CUB', 'CYP', 'CZE', 'COD', 'DNK', 'DJI', 'DOM', 'ECU', 'EGY',
#        'SLV', 'GNQ', 'ERI', 'EST', 'ETH', 'FJI', 'FIN', 'FRA', 'GUF',
#        'GAB', 'GMB', 'GEO', 'DEU', 'GHA', 'GRC', 'GTM', 'GIN', 'GNB',
#        'GUY', 'HND', 'HUN', 'ISL', 'IND', 'IDN', 'IRN', 'IRQ', 'IRL',
#        'ISR', 'ITA', 'JAM', 'JPN', 'JOR', 'KAZ', 'KEN', 'KOS', 'KWT',
#        'KGZ', 'LAO', 'LVA', 'LBN', 'LSO', 'LBR', 'LBY', 'LTU', 'LUX',
#        'MKD', 'MDG', 'MWI', 'MYS', 'MLI', 'MRT', 'MUS', 'MEX', 'MDA',
#        'MNG', 'MNE', 'MAR', 'MOZ', 'MMR', 'NAM', 'NPL', 'NLD', 'NZL',
#        'NIC', 'NER', 'NGA', 'PRK', 'NOR', 'OMN', 'PAK', 'PAN', 'PNG',
# ...

# %%
#The data contains 164 countries:
len(power_data['country'].unique())
# Out:
# 164

# %% [markdown]
# The US has the most data entires, followed by China, followed by Great Britain, France and Canada:

# %%
#The US has the most data rows, followed by China, followed by Great Britain, France and Canada:
number_of_plants = power_data['country'].value_counts()
number_of_plants.head(30)
# Out:
# USA    8119
# CHN    2901
# GBR    2567
# BRA    2340
# FRA    2018
# CAN    1154
# DEU     980
# IND     845
# ESP     613
# PRT     462
# CZE     450
# AUS     419
# JPN     325
# NOR     306
# CHL     253
# MEX     251
# ITA     247
# ARG     241
# VNM     219
# FIN     184
# THA     167
# SWE     167
# CHE     166
# IDN     158
# RUS     157
# KOR     124
# AUT     103
# IRN     100
# ZAF      98
# PHL      98
# Name: country, dtype: int64

# %%
ax = power_data['country'].value_counts().sort_values(ascending=False)[:20].plot.bar(x = 'Country', y = '', title = 'Electricity Generating Facilities by Country', rot = 90, figsize = (12, 10), fontsize =15)
ax.set_xlabel("Country", fontsize=15)
ax.set_ylabel("Number of Power Generating Facilities", fontsize=15)
plt.show()

# %%
capacity = power_data.groupby('country')['capacity_mw'].sum().round(2)

# %%
#The data shows China has the most generation capacity in 2017. (1,237 GW) Followed by the USA (1,183 GW), 
#Then India in third place (273 GW).
capacity.sort_values(ascending=False).head(20)
# Out:
# country
# CHN    1237478.38
# USA    1183855.55
# IND     273030.13
# JPN     210594.75
# RUS     182752.00
# BRA     145788.47
# CAN     143455.20
# FRA     109333.33
# DEU     108429.77
# KOR      93391.78
# SAU      84218.55
# GBR      80528.30
# ESP      76102.07
# ITA      71046.96
# AUS      66193.79
# IRN      61288.10
# MEX      59700.50
# TUR      49482.10
# ZAF      49456.30
# UKR      47320.00
# Name: capacity_mw, dtype: float64

# %% [markdown]
# The data shows China has the most generation capacity in 2017. (1,237 GW) Followed by the USA (1,183 GW),
# Then India in third place (273 GW).

# %%
ax = power_data.groupby('country')['capacity_mw'].sum().round(2).sort_values(ascending=False)[:20].plot.bar(x = 'Country', y = '', title = 'Electricity Generation Capacity by Country', rot = 90, figsize = (12, 10), fontsize =15)
ax.set_xlabel("Country", fontsize=15)
ax.set_ylabel("Total Generated MW", fontsize=15)
plt.show()

# %%
#I check the generation capacity of my origin country Ethiopia. 
#The output (4GW) is consistent with what I know from other sources.
print('Ethiopia produced ' + str(capacity['ETH']) + ' MW of electricity in 2017')
# Out:
# Ethiopia produced 4023.9 MW of electricity in 2017

# %%
#One insight I already gained from the data is that even though the US has three times as many rows (generating facilities) 
#than China, China still outputs more electricity than the US. This means the average capacity of each Chinese 
#unit is higher than the US
print('USA has ' + str(number_of_plants['USA']) + ' generating plants')
print('China has ' + str(number_of_plants['CHN']) + ' generating plants')
print('But China produces ' + str(capacity['CHN']) + ' MW, while US only produces ' + str(capacity['USA']) + " MW")
# Out:
# USA has 8119 generating plants
# China has 2901 generating plants
# But China produces 1237478.38 MW, while US only produces 1183855.55 MW

# %% [markdown]
# Next, I average the capacity by plant for the world:

# %%
#Next, I average the plant capacity for the world:
power_data['capacity_mw'].mean()

#Then I average it by country:
average_capacity_by_country= power_data.groupby('country_long')['capacity_mw'].mean()
average_capacity_by_country = average_capacity_by_country.sort_values(ascending=False)
print(average_capacity_by_country.head(20))

#From above code we see that the USA and China are not top on the list of having the largest average plant size:
# Paraguay is top on list followed by Kuwait and Ukraine.
# Out:
# country_long
# Paraguay                2920.000000
# Kuwait                  2227.437500
# Ukraine                 1526.451613
# Russia                  1164.025478
# Taiwan                  1103.320000
# United Arab Emirates    1096.555556
# Bahrain                 1083.042857
# Saudi Arabia             979.285465
# Singapore                975.714286
# Qatar                    879.000000
# Uzbekistan               847.866667
# Luxembourg               840.500000
# Zimbabwe                 835.000000
# Egypt                    777.302326
# Mozambique               761.666667
# South Korea              753.159516
# Kosovo                   739.000000
# Venezuela                723.162791
# Kazakhstan               694.780000
# Serbia                   663.166667
# Name: capacity_mw, dtype: float64

# %% [markdown]
# Next I compare the average generating capacity of a Chinese plant and compare it to a USA plant.

# %%
#I will now see the average generating capacity of a Chinese plant:
#And compare it to the average generating capacity of a US plant:
print('Average American plant:' + str(average_capacity_by_country['United States of America']) + 'MW')
print('Average Chinese plant: ' + str(average_capacity_by_country['China']) + 'MW')

#Like the preliminary data exploration suggested, a Chinese plant is on average about 3 times bigger than a US
#plant. That is why China generates more electricity than the US even though China has 1/3 the number of plants
#on this dataset than does the US
# Out:
# Average American plant:145.81297573592803MW
# Average Chinese plant: 426.56958979662176MW

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# I also graph the average plant capacity across the world.

# %%
plt.hist(average_capacity_by_country, bins = 50)
plt.xlabel('Average Capacity (MW) by plant')
plt.ylabel('Number of countries')
plt.show()

# %% [markdown]
# We see a large number of small power plants

# %%
plt.hist(power_data['capacity_mw'], range = (0, 200), bins = 30)
plt.xlabel('Capacity (MW)')
plt.ylabel('Number of facilities')
plt.show()

# %% [markdown]
# I create the graph again by limiting the range

# %%
plt.hist(power_data['capacity_mw'], range = (0, 50), bins = 20)
plt.xlabel('Capacity (MW)')
plt.ylabel('Number of facilities')
plt.show()

# %% [markdown]
# I limit the graph range even more to get a granular picture of these small power plant sizes

# %% [markdown]
# The data shows us that a significant amount of generation capacity is very small generating plants.
# Almost half the data entries are less than 10MW of generation capacity.

# %%
power_data.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'fuel1', 'fuel2', 'fuel3', 'fuel4',
#        'commissioning_year', 'owner', 'source', 'url', 'geolocation_source',
#        'year_of_capacity_data', 'generation_gwh_2013', 'generation_gwh_2014',
#        'generation_gwh_2015', 'generation_gwh_2016',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
#Here I check a list of the unique fuel types
#I use only the fuel1 column because the fuel2 - fuel4 columns are mostly empty
#Some plants have a dual fuel capacity, but my preliminary analysis shows that most plants consume
#the same type of fuel for the most part.
power_data['fuel1'].unique()
# Out:
# array(['Hydro', 'Gas', 'Other', 'Oil', 'Wind', 'Nuclear', 'Coal', 'Solar',
#        'Waste', 'Biomass', 'Wave and Tidal', 'Geothermal', nan,
#        'Cogeneration', 'Storage', 'Petcoke'], dtype=object)

# %% [markdown]
# Here I check a list of the unique fuel types.
# I use only the fuel1 column because the fuel2 - fuel4 columns are mostly empty.
# Some power plants have a dual fuel capacity, but most plants consume
# the same type of fuel for the most part.

# %% [markdown]
# Next, I check the world electricity generation by the sources of fuel(energy).
# I see from the calculation below that sadly coal is still the number one source of electricity around the world.
# Followed by Natural Gas, then Hydroelectric.

# %%
#Next, I check the world electricity generation by the sources of fuel(energy).
#I see from the calculation below that sadly Coal is still the number one source of electricity around the world.
#Followed by Natural Gas, then Hydroelectric.
energy_by_source = power_data.groupby('fuel1')['capacity_mw'].sum().round(2)
energy_by_source.sort_values()
# Out:
# fuel1
# Storage               348.60
# Petcoke               486.30
# Wave and Tidal        552.20
# Other                2190.10
# Cogeneration         4575.00
# Geothermal          12551.15
# Waste               20489.05
# Biomass             30457.10
# Solar               57645.33
# Wind               232799.93
# Nuclear            408612.56
# Oil                477971.83
# Hydro             1045867.32
# Gas               1179515.75
# Coal              1860150.40
# Name: capacity_mw, dtype: float64

# %%
#The above data in graphical form is below
#Again from the graph we see coal dominating electricity generation across the world.
ax = capacity_by_fuel_type_graph = energy_by_source.sort_values(ascending = False).plot.bar(rot=90, title = 'World Electricity Generation by Fuel Type, 2017', figsize = (12,10), fontsize =15)
ax.set_xlabel("Fuel Type", fontsize=15)
ax.set_ylabel("Generated MW", fontsize=15)
plt.show()

# %% [markdown]
# Next, I will look at the same generation by fuel type data for China and the US.
# First I look at the USA

# %%
#For the USA
energy_by_source_usa = power_data[power_data['country'] == 'USA'].groupby('fuel1')['capacity_mw'].sum().round(2)
ax = energy_by_source_usa.sort_values(ascending=False).plot.bar(rot=90, title = 'USA electricity generation by fuel type, 2017', figsize = (12,10), fontsize =15)
ax.set_xlabel("Fuel Type", fontsize=15)
ax.set_ylabel("Generated MW", fontsize=15)
plt.show()
#We see that coal is still the top fuel source for the USA.

# %% [markdown]
# Now I look at China:

# %%
#Now I look at China:
energy_by_source_china = power_data[power_data['country'] == 'CHN'].groupby('fuel1')['capacity_mw'].sum().round(2)
ax =energy_by_source_china.sort_values(ascending=False).plot.bar(rot=90, title = 'China\'s electricity generation by fuel type, 2017', figsize = (12, 10), fontsize =15)
ax.set_xlabel("Fuel Type", fontsize=15)
ax.set_ylabel("Generated MW", fontsize=15)
plt.show()

#We see that coal is the top fuel source for China.


#Infact, we see that coal is a much bigger and widely used fuel source in China than it is in the USA.

# %% [markdown]
# We see that coal is the top fuel source for China.
#
# Infact, we see that coal is a much bigger share of the electric mix in China than in the USA.

# %% [markdown]
# Next I look at the estimated generation growth for the near future by Country:

# %%
a = power_data.groupby('country')['estimated_generation_gwh'].sum().round(2)[:50]
a.sort_values(ascending=False)
# Out:
# country
# CHN    5621544.0
# CAN     655944.0
# DEU     627697.0
# BRA     590632.0
# ESP     278750.0
# AUS     248298.0
# ARG     138806.0
# ARE     108506.0
# CHL      73428.0
# COL      67719.0
# BEL      67323.0
# CHE      67258.0
# DZA      63079.0
# BGD      55696.0
# AUT      54075.0
# EGY      45324.0
# BGR      43666.0
# BLR      34042.0
# DNK      30559.0
# BHR      27253.0
# AZE      24549.0
# ECU      23812.0
# CUB      18605.0
# DOM      18541.0
# BIH      16086.0
# AGO       9480.0
# CRI       9298.0
# COD       8831.0
# BOL       8379.0
# ARM       7746.0
# CIV       7708.0
# CMR       6850.0
# ALB       4724.0
# BRN       4461.0
# CYP       4033.0
# BWA       2263.0
# COG       1740.0
# EST        716.0
# ERI        368.0
# BEN        183.0
# ATA          0.0
# CAF          0.0
# BDI          0.0
# BFA          0.0
# BTN          0.0
# CPV          0.0
# CZE          0.0
# DJI          0.0
# ESH          0.0
# AFG          0.0
# ...

# %% [markdown]
# China's estimated generation growth is insane. The data for China seems to be wrong.

# %%
ax = a.sort_values(ascending=False)[:20].plot.bar(x = 'Country', y = '', title = 'Planned Generation Growth by Country', rot = 90, figsize = (12, 10), fontsize =15)
ax.set_xlabel("Country", fontsize=15)
ax.set_ylabel("Growth in Generation, MW", fontsize=15)
plt.show()

# %%
#I plot the above data again without China, because it is an outlier:
#USA does not make it in the top 20 list
ax = a.sort_values(ascending=False)[1:20].plot.bar(x = 'Country', y = '', title = 'Planned growth in Electricity Generation by Country', rot = 90, figsize = (12, 10), fontsize =15)
ax.set_xlabel("Country", fontsize=15)
ax.set_ylabel("Growth in Generation, MW", fontsize=15)
plt.show()

# %% [markdown]
# I plot the data again without China, because it is an outlier.
# Notice that USA does not make it in the top 20 list

# %%
plt.scatter(power_data['capacity_mw'], power_data['estimated_generation_gwh'])
plt.xlabel("Current Capacity, MW", fontsize=15)
plt.ylabel("Growth in Generation, MW", fontsize=15)
plt.show()

# %% [markdown]
# From the scatterplot, current capacity is positively correlated with future generation growth.

# %%
power_data.head()
# Out:
#   country country_long                                               name  \
# 0     AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1     AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 2     AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 3     AFG  Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 4     AFG  Afghanistan            Northwest Kabul Power Plant Afghanistan
#
#       gppd_idnr  capacity_mw  latitude  longitude  fuel1 fuel2 fuel3  \
# 0  GEODB0040538        33.00   32.3220    65.1190  Hydro   NaN   NaN
# 1  GEODB0040541        66.00   34.5560    69.4787  Hydro   NaN   NaN
# 2  GEODB0040534       100.00   34.6410    69.7170  Hydro   NaN   NaN
# 3  GEODB0040536        11.55   34.4847    70.3633  Hydro   NaN   NaN
# 4  GEODB0040540        42.00   34.5638    69.1134    Gas   NaN   NaN
#
#              ...            owner  source                                 url  \
# ...

# %%
import matplotlib.pyplot as plt
ax=power_data.plot(kind="scatter", x="longitude", y="latitude", alpha=.9, title='Location of all power plants across the world',  figsize = (16, 10))
ax.set_xlim(-190,190)
ax.set_ylim(-70,80)
plt.show()

# %%
#World Coal plant loactions
#China coal plant loacations.
china = power_data[power_data['fuel1'] == 'Coal']
ax= china.plot(kind="scatter", x="longitude", y="latitude", alpha=.9, title= 'Coal plants', figsize = (13, 8))
ax.set_xlim(-190,190)
ax.set_ylim(-70,80)
plt.show()

# %%
#World Coal plant loactions
#China coal plant loacations.
china = power_data[power_data['fuel1'] == 'Gas']
ax= china.plot(kind="scatter", x="longitude", y="latitude", alpha=.9, title= 'Gas Plants', figsize = (14, 9))
ax.set_xlim(-190,190)
ax.set_ylim(-70,80)
plt.show()

# %%
power_data['fuel1'].unique()
# Out:
# array(['Hydro', 'Gas', 'Other', 'Oil', 'Wind', 'Nuclear', 'Coal', 'Solar',
#        'Waste', 'Biomass', 'Wave and Tidal', 'Geothermal', nan,
#        'Cogeneration', 'Storage', 'Petcoke'], dtype=object)

# %%
#World Coal plant loactions
#China coal plant loacations.
china = power_data[power_data['fuel1'] == 'Nuclear']
ax= china.plot(kind="scatter", x="longitude", y="latitude", alpha=.9, title= 'Nuclear Plants', figsize = (14, 9))
ax.set_xlim(-190,190)
ax.set_ylim(-70,80)
plt.show()

# %%
#World Coal plant loactions
#China coal plant loacations.
china = power_data[power_data['fuel1'] == 'Hydro']
ax= china.plot(kind="scatter", x="longitude", y="latitude", alpha=.9, title='Hydro Plants', figsize = (14, 9))
ax.set_xlim(-190,190)
ax.set_ylim(-70,80)
plt.show()

# %%
#World Coal plant loactions
#China coal plant loacations.
china = power_data[power_data['fuel1'] == 'Geothermal']
ax= china.plot(kind="scatter", x="longitude", y="latitude", alpha=.9, title='Geothermal Plants', figsize = (14, 9))
ax.set_xlim(-190,190)
ax.set_ylim(-70,80)
plt.show()

# %%
#World Coal plant loactions
#China coal plant loacations.
china = power_data[power_data['fuel1'] == 'Wind']
ax= china.plot(kind="scatter", x="longitude", y="latitude", alpha=.9, title='Wind Plants', figsize = (14, 9))
ax.set_xlim(-190,190)
ax.set_ylim(-70,80)
plt.show()

# %%
#World Coal plant loactions
#China coal plant loacations.
china = power_data[power_data['fuel1'] == 'Solar']
ax= china.plot(kind="scatter", x="longitude", y="latitude", alpha=.9, title='Solar Plants', figsize = (14, 9))
ax.set_xlim(-190,190)
ax.set_ylim(-70,80)
plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
# %matplotlib inline

# %%
fig = plt.figure(figsize = (10,5))
ax = fig.add_subplot(1,1,1, projection = ccrs.Robinson())
ax.set_global()
ax.stock_img()
ax.coastlines()
ax.plot(74.0060, 40.7128, 'o', color = 'r', transform = ccrs.PlateCarree())
plt.show()
